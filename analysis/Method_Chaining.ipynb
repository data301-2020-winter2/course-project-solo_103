# %%
import pandas as pd
df = pd.read_csv("../data/raw/tcc_ceds_music.csv")
df=(df.rename(columns = {"artist_name":"Artist","track_name":"Title","release_date":"Year"})
.drop(columns=["Unnamed: 0","lyrics","age","len"])
.dropna()
.reset_index()
.drop(columns="index")
.assign(Decade=df["release_date"]-df["release_date"]%10)
   )
df.head()
# Out:
#                  Artist                 Title  Year genre    dating  violence  \
# 0                mukesh  mohabbat bhi jhoothi  1950   pop  0.000598  0.063746
# 1         frankie laine             i believe  1950   pop  0.035537  0.096777
# 2           johnnie ray                   cry  1950   pop  0.002770  0.002770
# 3           pérez prado              patricia  1950   pop  0.048249  0.001548
# 4  giorgos papadopoulos    apopse eida oneiro  1950   pop  0.001350  0.001350
#
#    world/life  night/time  shake the audience  family/gospel  ...   sadness  \
# 0    0.000598    0.000598            0.000598       0.048857  ...  0.380299
# 1    0.443435    0.001284            0.001284       0.027007  ...  0.001284
# 2    0.002770    0.002770            0.002770       0.002770  ...  0.002770
# 3    0.001548    0.001548            0.021500       0.001548  ...  0.225889
# 4    0.417772    0.001350            0.001350       0.001350  ...  0.068800
#
# ...

# %%
import pandas as pd
def load_and_process(path):
    df1=(pd.read_csv(path).dropna()
    .reset_index()
    .drop(columns="index"))
    
    df2=(df1
    .rename(columns = {"artist_name":"Artist","track_name":"Title","release_date":"Year"})
    .drop(columns=["Unnamed: 0","lyrics","age","len"])
    .assign(Decade=df1["release_date"]-df1["release_date"]%10)
   )
    return df2

# %%
load_and_process("../data/raw/tcc_ceds_music.csv")
# Out:
#                      Artist                          Title  Year    genre  \
# 0                    mukesh           mohabbat bhi jhoothi  1950      pop
# 1             frankie laine                      i believe  1950      pop
# 2               johnnie ray                            cry  1950      pop
# 3               pérez prado                       patricia  1950      pop
# 4      giorgos papadopoulos             apopse eida oneiro  1950      pop
# ...                     ...                            ...   ...      ...
# 28367               mack 10                10 million ways  2019  hip hop
# 28368                m.o.p.  ante up (robbin hoodz theory)  2019  hip hop
# 28369                  nine                  whutcha want?  2019  hip hop
# 28370            will smith                         switch  2019  hip hop
# 28371                 jeezy                         r.i.p.  2019  hip hop
#
#          dating  violence  world/life  night/time  shake the audience  \
# ...
